# %%
# !pip install yfinance alpha_vantage matplotlib scikit-learn keras tensorflow

# %%
# %pip install yfinance

# %%
import yfinance as yf
import pandas as pd
# Indian
tcs=yf.download("TCS.NS",start="2020-01-01", end="2025-09-30")
adani=yf.download("ADANIENT.NS",start="2020-01-01", end="2025-09-30")
hdfc=yf.download("HDFCBANK.NS",start="2020-01-01", end="2025-09-30")
# Japan
nintendo=yf.download("7974.T",start="2020-01-01", end="2025-09-30")
sony=yf.download("6758.T",start="2020-01-01", end="2025-09-30")
honda=yf.download("7267.T",start="2020-01-01", end="2025-09-30")
#Hong Kong
xiaomi=yf.download("1810.HK",start="2020-01-01", end="2025-09-30")
huawei=yf.download("6881.HK",start="2020-01-01", end="2025-09-30")
alibaba=yf.download("9988.HK",start="2020-01-01", end="2025-09-30")
# Out:
# /tmp/ipython-input-589384049.py:4: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   tcs=yf.download("TCS.NS",start="2020-01-01", end="2025-09-30")
# [*********************100%***********************]  1 of 1 completed
# /tmp/ipython-input-589384049.py:5: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   adani=yf.download("ADANIENT.NS",start="2020-01-01", end="2025-09-30")
# [*********************100%***********************]  1 of 1 completed
# /tmp/ipython-input-589384049.py:6: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   hdfc=yf.download("HDFCBANK.NS",start="2020-01-01", end="2025-09-30")
# [*********************100%***********************]  1 of 1 completed
# /tmp/ipython-input-589384049.py:8: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   nintendo=yf.download("7974.T",start="2020-01-01", end="2025-09-30")
# ...

# %%
#Data Preprocessing

df=tcs=yf.download("TCS.NS",start="2020-01-01", end="2025-09-30")
df=df.reset_index()
df['MA50']=df['Close'].rolling(window=50).mean() # 50-day moving average
df['MA200'] =df['Close'].rolling(window=200).mean() # 200-day moving average
# Calculate daily returns and volatility
df['Return'] =df['Close'].pct_change()   # Daily returns
# Annualized volatility (assuming 252 trading days in a year)
df['Volatility'] = df['Return'].rolling(window=50).std() * (252**0.5) # 50-day rolling volatility
# Drop rows with NaN values resulting from calculations
df=df.dropna()   # Remove rows with NaN values
#Adani
adani=yf.download("ADANIENT.NS",start="2020-01-01", end="2025-09-30")
adani.dropna(inplace=True)
adani['Date']=adani.index
adani.reset_index(drop=True, inplace=True)
adani['MA50']=adani['Close'].rolling(window=50).mean() # 50-day moving average
adani['MA200'] =adani['Close'].rolling(window=200).mean() # 200-day moving average
adani['Return']=adani['Close'].pct_change()   # Daily returns
adani['Volatility'] = adani['Return'].rolling(window=50).std() * (252**0.5) # 50-day rolling volatility
adani.dropna(inplace=True)
#HDFC
hdfc=yf.download("HDFCBANK.NS",start="2020-01-01", end="2025-09-30")
hdfc.dropna(inplace=True)
hdfc['Date']=hdfc.index
hdfc.reset_index(drop=True, inplace=True)
hdfc['MA50']=hdfc['Close'].rolling(window=50).mean() # 50-day moving average
hdfc['MA200'] =hdfc['Close'].rolling(window=200).mean() # 200-day moving average
hdfc['Return']=hdfc['Close'].pct_change()
hdfc['Volatility'] = hdfc['Return'].rolling(window=50).std() * (252**0.5) # 50-day rolling volatility
hdfc.dropna(inplace=True)

#Japan
nintendo=yf.download("7974.T",start="2020-01-01", end="2025-09-30")
nintendo.dropna(inplace=True)
nintendo['Date']=nintendo.index
nintendo.reset_index(drop=True, inplace=True)
nintendo['MA50']=nintendo['Close'].rolling(window=50).mean() # 50-day moving average
nintendo['MA200'] =nintendo['Close'].rolling(window=200).mean() # 200-day moving average
nintendo['Return']=nintendo['Close'].pct_change()
nintendo['Volatility'] = nintendo['Return'].rolling(window=50).std() * (252**0.5) # 50-day rolling volatility
nintendo.dropna(inplace=True)
#sony
sony=yf.download("6758.T",start="2020-01-01", end="2025-09-30")
sony.dropna(inplace=True)
sony['Date']=sony.index
sony.reset_index(drop=True, inplace=True)
sony['MA50']=sony['Close'].rolling(window=50).mean() # 50-day moving average
sony['MA200'] =sony['Close'].rolling(window=200).mean() # 20
sony['Return']=sony['Close'].pct_change()
sony['Volatility'] = sony['Return'].rolling(window=50).std() * (252**0.5) # 50-day rolling volatility
sony.dropna(inplace=True)
#Honda
honda=yf.download("7267.T",start="2020-01-01", end="2025-09-30")
honda.dropna(inplace=True)
honda['Date']=honda.index
honda.reset_index(drop=True, inplace=True)
honda['MA50']=honda['Close'].rolling(window=50).mean() # 50-day moving average
honda['MA200'] =honda['Close'].rolling(window=200).mean() #
honda['Return']=honda['Close'].pct_change()
honda['Volatility'] = honda['Return'].rolling(window=50).std() * (252**0.5) # 50-day rolling volatility
honda.dropna(inplace=True)

#Hong Kong
xiaomi=yf.download("1810.HK",start="2020-01-01", end="2025-09-30")
xiaomi.dropna(inplace=True)
xiaomi['Date']=xiaomi.index
xiaomi.reset_index(drop=True, inplace=True)
xiaomi['MA50']=xiaomi['Close'].rolling(window=50).mean() # 50-day moving average
xiaomi['MA200'] =xiaomi['Close'].rolling(window=200).mean() # 200-day moving average
xiaomi['Return']=xiaomi['Close'].pct_change()
xiaomi['Volatility'] = xiaomi['Return'].rolling(window=50).std() * (252**0.5) # 50-day rolling volatility
xiaomi.dropna(inplace=True)
#huawei
huawei=yf.download("6881.HK",start="2020-01-01", end="2025-09-30")
huawei.dropna(inplace=True)
huawei['Date']=huawei.index
huawei.reset_index(drop=True, inplace=True)
huawei['MA50']=huawei['Close'].rolling(window=50).mean() # 50-day moving average
huawei['MA200'] =huawei['Close'].rolling(window=200).mean() # 20
huawei['Return']=huawei['Close'].pct_change()
huawei['Volatility'] = huawei['Return'].rolling(window=50).std() * (252**0.5) # 50-day rolling volatility
huawei.dropna(inplace=True)
#alibaba
alibaba=yf.download("9988.HK",start="2020-01-01", end="2025-09-30")
alibaba.dropna(inplace=True)
alibaba['Date']=alibaba.index
alibaba.reset_index(drop=True, inplace=True)
alibaba['MA50']=alibaba['Close'].rolling(window=50).mean() # 50-day moving average
alibaba['MA200'] =alibaba['Close'].rolling(window=200).mean() # 200-day moving average
alibaba['Return']=alibaba['Close'].pct_change()
alibaba['Volatility'] = alibaba['Return'].rolling(window=50).std() * (252**0.5) # 50-day rolling volatility
alibaba.dropna(inplace=True)
# Out:
# /tmp/ipython-input-3229109014.py:3: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df=tcs=yf.download("TCS.NS",start="2020-01-01", end="2025-09-30")
# [*********************100%***********************]  1 of 1 completed
# /tmp/ipython-input-3229109014.py:14: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   adani=yf.download("ADANIENT.NS",start="2020-01-01", end="2025-09-30")
# [*********************100%***********************]  1 of 1 completed
# /tmp/ipython-input-3229109014.py:24: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   hdfc=yf.download("HDFCBANK.NS",start="2020-01-01", end="2025-09-30")
# [*********************100%***********************]  1 of 1 completed
# /tmp/ipython-input-3229109014.py:35: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   nintendo=yf.download("7974.T",start="2020-01-01", end="2025-09-30")
# ...

# %%
print("INDIAN TCS\n\n",df.head())
# Out:
# INDIAN TCS
#
#  Price        Date        Close         High          Low         Open  \
# Ticker                  TCS.NS       TCS.NS       TCS.NS       TCS.NS
# 199    2020-10-19  2532.137939  2590.455834  2527.515506  2590.455834
# 200    2020-10-20  2557.771973  2577.289017  2538.114716  2544.698293
# 201    2020-10-21  2498.380127  2567.110421  2486.847410  2557.772078
# 202    2020-10-22  2494.411377  2508.885808  2463.548336  2484.933050
# 203    2020-10-23  2509.025635  2523.219868  2493.430650  2509.959469
#
# Price    Volume         MA50        MA200    Return Volatility
# Ticker   TCS.NS
# 199     3331194  2268.043262  1982.812968 -0.018728   0.299837
# 200     3406273  2276.744570  1985.671201  0.010123   0.299456
# 201     4570143  2284.311982  1988.278060 -0.023220   0.305404
# 202     5262294  2292.219385  1990.668079 -0.001589   0.304102
# 203     3499091  2300.473008  1993.132083  0.005859   0.303930

# %% [markdown]
# # Exploratory Data Analysis

# %%
#Exploaratory Data Analysis (EDA) of NSE
import matplotlib.pyplot as plt
plt.figure(figsize=(14,7))
plt.plot(df['Date'], df['Close'], label='Close Price')
plt.plot(df['Date'], df['MA50'], label='50-Day MA')
plt.plot(df['Date'], df['MA200'], label='200-Day MA')
plt.title('TCS Stock Price with Moving Averages')
plt.xlabel('Date')
plt.ylabel('Price (INR)')
plt.legend()
plt.show()
# Daily Returns Distribution
plt.figure(figsize=(10,5))
plt.hist(df['Return'], bins=50, alpha=0.7, color='green')
plt.title('Daily Returns Distribution')
plt.xlabel('Daily Return')
plt.ylabel('Frequency')
plt.show()
# Volatility Over Time
plt.figure(figsize=(14,7))
plt.plot(df['Date'], df['Volatility'], label='Volatility', color='orange')
plt.title('50-Day Rolling Volatility')
plt.xlabel('Date')
plt.ylabel('Volatility')
plt.legend()
plt.show()

# %%
#Exploratory Data Analysis of Adani
plt.figure(figsize=(14,7))
plt.plot(adani['Date'], adani['Close'], label='Close Price')
plt.plot(adani['Date'], adani['MA50'], label='50-Day MA')
plt.plot(adani['Date'], adani['MA200'], label='200-Day MA')
plt.title('Adani Enterprises Stock Price with Moving Averages')
plt.xlabel('Date')
plt.ylabel('Price (INR)')
plt.legend()
plt.show()
#Daily Return Distribution
plt.figure(figsize=(10,5))
plt.hist(adani['Return'], bins=50, alpha=0.7, color='green')
plt.title('Daily Returns Distribution')
plt.xlabel('Daily Return')
plt.ylabel('Frequency')
plt.show()
#Volatility Over Time
plt.figure(figsize=(14,7))
plt.plot(adani['Date'], adani['Volatility'], label='Volatility', color='orange')
plt.title('50-Day Rolling Volatility')
plt.xlabel('Date')
plt.ylabel('Volatility')
plt.legend()
plt.show()

# %%
# EDA of HDFC
plt.figure(figsize=(14,7))
plt.plot(hdfc['Date'], hdfc['Close'], label='Close Price')
plt.plot(hdfc['Date'], hdfc['MA50'], label='50-Day MA')
plt.plot(hdfc['Date'], hdfc['MA200'], label='200-Day MA')
plt.title('HDFC Bank Stock Price with Moving Averages')
plt.xlabel('Date')
plt.ylabel('Price (INR)')
plt.legend()
plt.show()
#Daily Returns Distribution
plt.figure(figsize=(10,5))
plt.hist(hdfc['Return'], bins=50, alpha=0.7, color='green')
plt.title('Daily Returns Distribution')
plt.xlabel('Daily Return')
plt.ylabel('Frequency')
plt.show()
#Volatility Over Time
plt.figure(figsize=(14,7))
plt.plot(hdfc['Date'], hdfc['Volatility'], label='Volatility', color='orange')
plt.title('50-Day Rolling Volatility')
plt.xlabel('Date')
plt.ylabel('Volatility')
plt.legend()
plt.show()

# %%
#EDA of Nintendo,Sony,Honda
plt.figure(figsize=(14,7))
plt.plot(nintendo['Date'],nintendo['Close'], label='Close Price')
plt.plot(nintendo['Date'],nintendo['MA50'], label='50-Day MA')
plt.plot(nintendo['Date'],nintendo['MA200'], label='200-Day MA')
plt.title('Nintendo Stock Price with Moving Averages')
plt.xlabel('Date')
plt.ylabel('Price (YEN)')
plt.legend()
plt.show()
#Daily Returns Distribution
plt.figure(figsize=(10,5))
plt.hist(nintendo['Return'], bins=50, alpha=0.7, color='green')
plt.title('Daily Returns Distribution')
plt.xlabel('Daily Return')
plt.ylabel('Frequency')
plt.show()
#Volatility Over Time
plt.figure(figsize=(14,7))
plt.plot(nintendo['Date'], nintendo['Volatility'], label='Volatility', color='orange')
plt.title('50-Day Rolling Volatility')
plt.xlabel('Date')
plt.ylabel('Volatility')
plt.legend()
plt.show()

# %%
#EDA of Sony
plt.figure(figsize=(14,7))
plt.plot(sony['Date'],sony['Close'], label='Close Price')
plt.plot(sony['Date'],sony['MA50'], label='50-Day MA')
plt.plot(sony['Date'],sony['MA200'], label='200-Day MA')
plt.title('Sony Stock Price with Moving Averages')
plt.xlabel('Date')
plt.ylabel('Price (YEN)')
plt.legend()
plt.show()
#Daily Returns Distribution
plt.figure(figsize=(10,5))
plt.hist(sony['Return'], bins=50, alpha=0.7, color='green')
plt.title('Daily Returns Distribution')
plt.xlabel('Daily Return')
plt.ylabel('Frequency')
plt.show()
#Volatility Over Time
plt.figure(figsize=(14,7))
plt.plot(sony['Date'], sony['Volatility'], label='Volatility', color='orange')
plt.title('50-Day Rolling Volatility')
plt.xlabel('Date')
plt.ylabel('Volatility')
plt.legend()
plt.show()

# %%
#EDA of Honda
plt.figure(figsize=(14,7))
plt.plot(honda['Date'],honda['Close'], label='Close Price')
plt.plot(honda['Date'],honda['MA50'], label='50-Day MA')
plt.plot(honda['Date'],honda['MA200'], label='200-Day MA')
plt.title('Honda Stock Price with Moving Averages')
plt.xlabel('Date')
plt.ylabel('Price (YEN)')
plt.legend()
plt.show()
#Daily Returns Distribution
plt.figure(figsize=(10,5))
plt.hist(honda['Return'], bins=50, alpha=0.7, color='green')
plt.title('Daily Returns Distribution')
plt.xlabel('Daily Return')
plt.ylabel('Frequency')
plt.show()
#Volatility Over Time
plt.figure(figsize=(14,7))
plt.plot(honda['Date'], honda['Volatility'], label='Volatility', color='orange')
plt.title('50-Day Rolling Volatility')
plt.xlabel('Date')
plt.ylabel('Volatility')
plt.legend()
plt.show()

# %%
#EDA of xiaomi,huawei,alibaba
plt.figure(figsize=(14,7))
plt.plot(xiaomi['Date'],xiaomi['Close'], label='Close Price')
plt.plot(xiaomi['Date'],xiaomi['MA50'], label='50-Day MA')
plt.plot(xiaomi['Date'],xiaomi['MA200'], label='200-Day MA')
plt.title('Xiaomi Stock Price with Moving Averages')
plt.xlabel('Date')
plt.ylabel('Price (HKD)')
plt.legend()
plt.show()
#Daily Returns Distribution
plt.figure(figsize=(10,5))
plt.hist(xiaomi['Return'], bins=50, alpha=0.7, color='green')
plt.title('Daily Returns Distribution')
plt.xlabel('Daily Return')
plt.ylabel('Frequency')
plt.show()
#Volatility Over Time
plt.figure(figsize=(14,7))
plt.plot(xiaomi['Date'], xiaomi['Volatility'], label='Volatility', color='orange')
plt.title('50-Day Rolling Volatility')
plt.xlabel('Date')
plt.ylabel('Volatility')
plt.legend()
plt.show()

# %%
#EDA of huawei
plt.figure(figsize=(14,7))
plt.plot(huawei['Date'],huawei['Close'], label='Close Price')
plt.plot(huawei['Date'],huawei['MA50'], label='50-Day MA')
plt.plot(huawei['Date'],huawei['MA200'], label='200-Day MA')
plt.title('Huawei Stock Price with Moving Averages')
plt.xlabel('Date')
plt.ylabel('Price (HKD)')
plt.legend()
plt.show()
#Daily Returns Distribution
plt.figure(figsize=(10,5))
plt.hist(huawei['Return'], bins=50, alpha=0.7, color='green')
plt.title('Daily Returns Distribution')
plt.xlabel('Daily Return')
plt.ylabel('Frequency')
plt.show()
#Volatility Over Time
plt.figure(figsize=(14,7))
plt.plot(huawei['Date'], huawei['Volatility'], label='Volatility', color='orange')
plt.title('50-Day Rolling Volatility')
plt.xlabel('Date')
plt.ylabel('Volatility')
plt.legend()
plt.show()

# %%
#EDA of alibaba
plt.figure(figsize=(14,7))
plt.plot(alibaba['Date'],alibaba['Close'], label='Close Price')
plt.plot(alibaba['Date'],alibaba['MA50'], label='50-Day MA')
plt.plot(alibaba['Date'],alibaba['MA200'], label='200-Day MA')
plt.title('Alibaba Stock Price with Moving Averages')
plt.xlabel('Date')
plt.ylabel('Price (HKD)')
plt.legend()
plt.show()
#Daily Returns Distribution
plt.figure(figsize=(10,5))
plt.hist(alibaba['Return'], bins=50, alpha=0.7, color='green')
plt.title('Daily Returns Distribution')
plt.xlabel('Daily Return')
plt.ylabel('Frequency')
plt.show()
#Volatility Over Time
plt.figure(figsize=(14,7))
plt.plot(alibaba['Date'], alibaba['Volatility'], label='Volatility', color='orange')
plt.title('50-Day Rolling Volatility')
plt.xlabel('Date')
plt.ylabel('Volatility')
plt.legend()
plt.show()

# %%
import yfinance as yf
import pandas as pd

# %%
jd=yf.download("9618.HK",start="2020-01-01", end="2025-09-30")
# Out:
# /tmp/ipython-input-3414331357.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   jd=yf.download("9618.HK",start="2020-01-01", end="2025-09-30")
# [*********************100%***********************]  1 of 1 completed

# %%
#Data Preprocessing

jd=yf.download("9618.HK",start="2020-01-01", end="2025-09-30")
jd=jd.reset_index()
jd['MA50']=jd['Close'].rolling(window=50).mean() # 50-day moving average
jd['MA200'] =jd['Close'].rolling(window=200).mean() # 200-day moving average
# Calculate daily returns and volatility
jd['Return'] =jd['Close'].pct_change()   # Daily returns
# Annualized volatility (assuming 252 trading days in a year)
jd['Volatility'] = jd['Return'].rolling(window=50).std() * (252**0.5) # 50-day rolling volatility
# Drop rows with NaN values resulting from calculations
jd=jd.dropna()   # Remove rows with NaN values
# Out:
# /tmp/ipython-input-2338246859.py:3: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   jd=yf.download("9618.HK",start="2020-01-01", end="2025-09-30")
# [*********************100%***********************]  1 of 1 completed

# %%
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout
from sklearn.metrics import mean_squared_error
import tensorflow as tf
import math
from sklearn.model_selection import train_test_split
import pickle
import matplotlib.pyplot as plt

# %% [markdown]
# # Forecasting Stock Prices

# %%
# %pip install keras

# %%
# %pip install tensorflow

# %%
jd.head()
# Out:
# Price        Date       Close        High         Low        Open   Volume  \
# Ticker                9618.HK     9618.HK     9618.HK     9618.HK  9618.HK
# 199    2021-04-12  305.645142  311.378447  299.714124  311.378447  5424736
# 200    2021-04-13  294.969299  304.261222  292.003790  301.691138  9310823
# 201    2021-04-14  302.481934  304.261227  299.714137  299.911820  5481245
# 202    2021-04-15  297.539429  299.714148  294.573919  299.516435  4915355
# 203    2021-04-16  299.516388  300.900286  295.760089  297.539382  3173306
#
# Price         MA50       MA200    Return Volatility
# Ticker
# 199     349.451625  310.043967 -0.021519   0.490559
# 200     347.798848  310.362265 -0.034929   0.494929
# 201     346.478208  310.720103  0.025469   0.497317
# 202     345.501568  311.080906 -0.016340   0.481134
# 203     344.655409  311.441710  0.006644   0.480953

# %%
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout
from sklearn.metrics import mean_squared_error
import tensorflow as tf
import math
from sklearn.model_selection import train_test_split
import pickle
import matplotlib.pyplot as plt
# --- One day ahead Stock Price Prediction using LSTM for JD_hk ---

scaler_jd = MinMaxScaler(feature_range=(0, 1))
scaled_data_jd = scaler_jd.fit_transform(jd[['Close', 'MA50', 'MA200', 'Volatility']])

# Save JD scaler + scaled data
pickle.dump(scaler_jd, open("jd_scaler.pkl", "wb"))
pickle.dump(scaled_data_jd, open("jd_scaled_data.pkl", "wb"))

# Create sequences
def create_sequences(data, seq_length):
    X, y = [], []
    for i in range(len(data) - seq_length):
        X.append(data[i:i + seq_length])
        y.append(data[i + seq_length, 0])  # predict Close
    return np.array(X), np.array(y)

seq_length = 60
X, y = create_sequences(scaled_data_jd, seq_length)

# Train-test split
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)

# Build LSTM model
model = Sequential()
model.add(LSTM(units=100, return_sequences=True, input_shape=(X.shape[1], X.shape[2])))
model.add(Dropout(0.2))
model.add(LSTM(units=50, return_sequences=False))
model.add(Dropout(0.2))
model.add(Dense(units=1))
model.compile(optimizer='adam', loss='mean_squared_error')

# Train
model.fit(x_train, y_train, epochs=150, batch_size=32, validation_data=(x_test, y_test))

# Predict
predictions = model.predict(x_test)
predictions = scaler_jd.inverse_transform(
    np.concatenate((predictions, np.zeros((predictions.shape[0], 3))), axis=1)
)[:,0]

# Rescale y_test
y_test_rescaled = scaler_jd.inverse_transform(
    np.concatenate((y_test.reshape(-1, 1), np.zeros((y_test.shape[0], 3))), axis=1)
)[:,0]

# RMSE
rmse = math.sqrt(mean_squared_error(y_test_rescaled, predictions))
print(f'Root Mean Squared Error (JD): {rmse}')

# Save Tencent model
model.save('jd_model.h5')

# Save scaler again (this time correct one)
with open("jd_scaler.pkl", "wb") as f:
    pickle.dump(scaler_jd, f)

# Forecasts
latest_data = scaled_data_jd[-seq_length:]
latest_data = np.expand_dims(latest_data, axis=0)
predicted_price = model.predict(latest_data)
predicted_price = scaler_jd.inverse_transform(
    np.concatenate((predicted_price, np.zeros((predicted_price.shape[0], 3))), axis=1)
)[:, 0]
print(f'Predicted Next Day Closing Price (JD): {predicted_price[0]}')

#mape
def mean_absolute_percentage_error(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100
mape = mean_absolute_percentage_error(y_test_rescaled, predictions)
print(f'Mean Absolute Percentage Error: {mape}%')
plt.figure(figsize=(14,7))
plt.plot(y_test_rescaled, label="Actual Price", color="blue")
plt.plot(predictions, label="Predicted Price", color="green", linestyle="--")
plt.title("JD Stock Price Prediction (LSTM)")
plt.xlabel("Time (days)")
plt.ylabel("Stock Price (CNY)")
plt.legend()
plt.show()
# Out:
# Epoch 1/150
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 6s 124ms/step - loss: 0.0735 - val_loss: 0.0020
# Epoch 2/150
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 68ms/step - loss: 0.0105 - val_loss: 0.0012
# Epoch 3/150
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - loss: 0.0060 - val_loss: 0.0013
# Epoch 4/150
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 68ms/step - loss: 0.0046 - val_loss: 0.0011
# Epoch 5/150
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - loss: 0.0043 - val_loss: 0.0012
# Epoch 6/150
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 67ms/step - loss: 0.0045 - val_loss: 0.0013
# Epoch 7/150
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step - loss: 0.0045 - val_loss: 0.0011
# Epoch 8/150
# ...

# %%
# --- One day ahead Stock Price Prediction using LSTM for Xiaomi ---

scaler_xiaomi = MinMaxScaler(feature_range=(0, 1))
scaled_data_xiaomi = scaler_xiaomi.fit_transform(xiaomi[['Close', 'MA50', 'MA200', 'Volatility']])

# Save Tencent scaler + scaled data
pickle.dump(scaler_xiaomi, open("xiaomi_scaler.pkl", "wb"))
pickle.dump(scaled_data_xiaomi, open("xiaomi_scaled_data.pkl", "wb"))

# Create sequences
def create_sequences(data, seq_length):
    X, y = [], []
    for i in range(len(data) - seq_length):
        X.append(data[i:i + seq_length])
        y.append(data[i + seq_length, 0])  # predict Close
    return np.array(X), np.array(y)

seq_length = 60
X, y = create_sequences(scaled_data_xiaomi, seq_length)

# Train-test split
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)

# Build LSTM model
model = Sequential()
model.add(LSTM(units=100, return_sequences=True, input_shape=(X.shape[1], X.shape[2])))
model.add(Dropout(0.2))
model.add(LSTM(units=50, return_sequences=False))
model.add(Dropout(0.2))
model.add(Dense(units=1))
model.compile(optimizer='adam', loss='mean_squared_error')

# Train
model.fit(x_train, y_train, epochs=150, batch_size=32, validation_data=(x_test, y_test))

# Predict
predictions = model.predict(x_test)
predictions = scaler_xiaomi.inverse_transform(
    np.concatenate((predictions, np.zeros((predictions.shape[0], 3))), axis=1)
)[:,0]

# Rescale y_test
y_test_rescaled = scaler_xiaomi.inverse_transform(
    np.concatenate((y_test.reshape(-1, 1), np.zeros((y_test.shape[0], 3))), axis=1)
)[:,0]

# RMSE
rmse = math.sqrt(mean_squared_error(y_test_rescaled, predictions))
print(f'Root Mean Squared Error (Xiaomi): {rmse}')

# Save Tencent model
model.save('xiaomi_model.h5')

# Save scaler again (this time correct one)
with open("xiaomi_scaler.pkl", "wb") as f:
    pickle.dump(scaler_xiaomi, f)

# Forecasts
latest_data = scaled_data_xiaomi[-seq_length:]
latest_data = np.expand_dims(latest_data, axis=0)
predicted_price = model.predict(latest_data)
predicted_price = scaler_xiaomi.inverse_transform(
    np.concatenate((predicted_price, np.zeros((predicted_price.shape[0], 3))), axis=1)
)[:, 0]
print(f'Predicted Next Day Closing Price (Xiaomi): {predicted_price[0]}')

#mape
def mean_absolute_percentage_error(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100
mape = mean_absolute_percentage_error(y_test_rescaled, predictions)
print(f'Mean Absolute Percentage Error: {mape}%')
plt.figure(figsize=(14,7))
plt.plot(y_test_rescaled, label="Actual Price", color="blue")
plt.plot(predictions, label="Predicted Price", color="green", linestyle="--")
plt.title("Xiaomi Stock Price Prediction (LSTM)")
plt.xlabel("Time (days)")
plt.ylabel("Stock Price (CNY)")
plt.legend()
plt.show()
# Out:
# Epoch 1/150
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 9s 150ms/step - loss: 0.0092 - val_loss: 0.0144
# Epoch 2/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 3s 81ms/step - loss: 0.0012 - val_loss: 0.0199
# Epoch 3/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 3s 88ms/step - loss: 9.4047e-04 - val_loss: 0.0066
# Epoch 4/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - loss: 8.6937e-04 - val_loss: 0.0052
# Epoch 5/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 3s 116ms/step - loss: 0.0010 - val_loss: 0.0141
# Epoch 6/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 3s 86ms/step - loss: 7.5495e-04 - val_loss: 0.0091
# Epoch 7/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step - loss: 7.4806e-04 - val_loss: 0.0117
# Epoch 8/150
# ...

# %%
# --- One day ahead Stock Price Prediction using LSTM for Huawei ---

scaler_huawei = MinMaxScaler(feature_range=(0, 1))
scaled_data_huawei = scaler_huawei.fit_transform(huawei[['Close', 'MA50', 'MA200', 'Volatility']])

# Save Tencent scaler + scaled data
pickle.dump(scaler_huawei, open("huawei_scaler.pkl", "wb"))
pickle.dump(scaled_data_huawei, open("huawei_scaled_data.pkl", "wb"))

# Create sequences
def create_sequences(data, seq_length):
    X, y = [], []
    for i in range(len(data) - seq_length):
        X.append(data[i:i + seq_length])
        y.append(data[i + seq_length, 0])  # predict Close
    return np.array(X), np.array(y)

seq_length = 60
X, y = create_sequences(scaled_data_huawei, seq_length)

# Train-test split
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)

# Build LSTM model
model = Sequential()
model.add(LSTM(units=100, return_sequences=True, input_shape=(X.shape[1], X.shape[2])))
model.add(Dropout(0.2))
model.add(LSTM(units=50, return_sequences=False))
model.add(Dropout(0.2))
model.add(Dense(units=1))
model.compile(optimizer='adam', loss='mean_squared_error')

# Train
model.fit(x_train, y_train, epochs=150, batch_size=32, validation_data=(x_test, y_test))

# Predict
predictions = model.predict(x_test)
predictions = scaler_huawei.inverse_transform(
    np.concatenate((predictions, np.zeros((predictions.shape[0], 3))), axis=1)
)[:,0]

# Rescale y_test
y_test_rescaled = scaler_huawei.inverse_transform(
    np.concatenate((y_test.reshape(-1, 1), np.zeros((y_test.shape[0], 3))), axis=1)
)[:,0]

# RMSE
rmse = math.sqrt(mean_squared_error(y_test_rescaled, predictions))
print(f'Root Mean Squared Error (Huawei): {rmse}')

# Save Tencent model
model.save('huawei_model.h5')

# Save scaler again (this time correct one)
with open("huawei_scaler.pkl", "wb") as f:
    pickle.dump(scaler_huawei, f)

# Forecasts
latest_data = scaled_data_huawei[-seq_length:]
latest_data = np.expand_dims(latest_data, axis=0)
predicted_price = model.predict(latest_data)
predicted_price = scaler_huawei.inverse_transform(
    np.concatenate((predicted_price, np.zeros((predicted_price.shape[0], 3))), axis=1)
)[:, 0]
print(f'Predicted Next Day Closing Price (Huawei): {predicted_price[0]}')

#mape
def mean_absolute_percentage_error(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100
mape = mean_absolute_percentage_error(y_test_rescaled, predictions)
print(f'Mean Absolute Percentage Error: {mape}%')
plt.figure(figsize=(14,7))
plt.plot(y_test_rescaled, label="Actual Price", color="blue")
plt.plot(predictions, label="Predicted Price", color="green", linestyle="--")
plt.title("Huawei Stock Price Prediction (LSTM)")
plt.xlabel("Time (days)")
plt.ylabel("Stock Price (CNY)")
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 8s 95ms/step - loss: 0.0046 - val_loss: 0.0357
# Epoch 2/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 3s 103ms/step - loss: 0.0017 - val_loss: 0.0032
# Epoch 3/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 3s 97ms/step - loss: 7.8739e-04 - val_loss: 0.0032
# Epoch 4/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - loss: 0.0017 - val_loss: 0.0064
# Epoch 5/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - loss: 0.0016 - val_loss: 0.0033
# Epoch 6/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - loss: 0.0013 - val_loss: 0.0026
# Epoch 7/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 3s 95ms/step - loss: 0.0020 - val_loss: 0.0029
# Epoch 8/150
# ...

# %%
# 30 day forecast for Alibaba
future_days = 30
future_predictions = []
current_sequence = scaled_data_huawei[-seq_length:]  # Start with the last 'seq_length' days
for _ in range(future_days):
    current_sequence_reshaped = np.expand_dims(current_sequence, axis=0)  # Reshape for model
    next_pred = model.predict(current_sequence_reshaped)
    future_predictions.append(next_pred[0, 0])
    # Update the sequence by appending the new prediction and removing the oldest entry
    next_entry = np.array([next_pred[0, 0], current_sequence[-1, 1], current_sequence[-1, 2], current_sequence[-1, 3]])  # Keep MA50, MA200, Volatility unchanged
    current_sequence = np.vstack((current_sequence[1:], next_entry))  # Slide the window
# Rescale future predictions back to original values
future_predictions_rescaled = scaler_huawei.inverse_transform(np.concatenate((np.array(future_predictions).reshape(- 1, 1), np.zeros((future_days, 3))), axis=1))[:, 0]
print("30-Day Future Price Predictions:", future_predictions_rescaled)

plt.figure(figsize=(14,7))
plt.plot(range(len(huawei)), huawei['Close'], label="Historical Price", color="blue")
plt.plot(range(len(huawei), len(huawei) + future_days), future_predictions_rescaled, label="30-Day Forecast", color="green", linestyle="--")
rmse = math.sqrt(mean_squared_error(y_test_rescaled, predictions))
upper_bound = future_predictions_rescaled + rmse
lower_bound = future_predictions_rescaled - rmse
plt.fill_between(range(len(huawei), len(huawei) + future_days), lower_bound, upper_bound, color='brown', alpha=0.3, label='Confidence Interval (±RMSE)')
plt.title("Huawei Industries Stock Price 30-Day Forecast (LSTM)")
plt.xlabel("Time (days)")
plt.ylabel("Stock Price (CNY)")
plt.legend()
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# ...
